# %%
firstname = "Arif"

if len(firstname) >= 3:
    print(firstname[0])  # Prints 1st letter
# Out:
# A

# %%
lastname = "Ali"
if len(lastname) >= 3:
    print(lastname[1]) # Prints 2nd letter
# Out:
# l

# %%
name = input("Enter the name:")
parts = name.split()
fn = parts[0] #Firstname =fn
ln = parts[1] #lastname =ln

print("First Name:", fn)
print("Last Name:", ln)
# Out:
# Enter the name: Arif Ali
# First Name: Arif
# Last Name: Ali

# %%
print("Enter 5 numbers:")
a = int(input())
b = int(input())
c = int(input())
d = int(input())
e = int(input())

avg = (a + b + c + d + e) / 5
print("Avg =", avg)
# Out:
# Enter 5 numbers:
#  1
#  2
#  3
#  4
#  5
# Avg = 3.0

# %%
fahrenheit = float(input("Enter the temp:\n"))
celsius = (fahrenheit -32)*5/9

print(f"{fahrenheit}Fahrenheit = {celsius:2f}Celsius")
# Out:
# Enter the temp:
#  100
# 100.0Fahrenheit = 37.777778Celsius

# %%
C = float(input ("Enter the temp:\n"))
F = (C*9/5) +32

print(f"{C}°C = {F:2f}°F")
# Out:
# Enter the temp:
#  37
# 37.0°C = 98.600000°F

# %%
number = int(input("Enter a number:"))

if number % 2 ==0:
    print(number, "is an even number.")
else:
    print(number, "is an odd number.")
# Out:
# Enter a number: 1
# 1 is an odd number.

# %%
number = int(input("Enter a number:"))

if number % 2 ==0:
    print(number, "is an even number.")
else:
    print(number, "is an odd number.")
# Out:
# Enter a number: 2
# 2 is an even number.

# %%
number = int(input("Enter the number:"))

for i in range(1, 11):
    print(number*i)
# Out:
# Enter the number: 5
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
